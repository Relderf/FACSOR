# %% [markdown]
# # Análisis básico de logs
# Este notebook ejecuta automáticamente el análisis definido en `log_utils.py` usando `server_log.csv`.

# %%
import importlib
import log_utils
importlib.reload(log_utils)

df = log_utils.ejecutar_analisis('server_log.csv')
# Out:
# Filas: 5000
# Rango temporal: 2026-05-20 00:02:40 -> 2026-05-24 05:14:47
# Nodos: ['srv-a', 'srv-b', 'srv-c']
# Tipos de evento: ['error', 'login', 'query', 'report', 'timeout', 'transfer']
